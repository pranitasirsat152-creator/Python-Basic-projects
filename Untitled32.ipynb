# %% [markdown]
# <a href="https://colab.research.google.com/github/pranitasirsat152-creator/Python-Basic-projects/blob/main/Untitled32.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
Uploaded = files.upload()
# Out:
#      <input type="file" id="files-04035aa8-7cab-44fd-a6b2-b7d6a6bfffa5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-04035aa8-7cab-44fd-a6b2-b7d6a6bfffa5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("heart.csv")
print(df.head(10))
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
# 5   39   M           NAP        120          339          0     Normal    170
# 6   45   F           ATA        130          237          0     Normal    170
# 7   54   M           ATA        110          208          0     Normal    142
# 8   37   M           ASY        140          207          0     Normal    130
# 9   48   F           ATA        120          284          0     Normal    120
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# ...

# %%
import pandas as pd


df = pd.read_csv("heart.csv")   # File name change kara jar vegla asel

print(df.head(10))
print("Shape:", df.shape)
print(df.info())
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
# 5   39   M           NAP        120          339          0     Normal    170
# 6   45   F           ATA        130          237          0     Normal    170
# 7   54   M           ATA        110          208          0     Normal    142
# 8   37   M           ASY        140          207          0     Normal    130
# 9   48   F           ATA        120          284          0     Normal    120
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# ...

# %%
print(df.isnull().sum())
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
print("Duplicate Rows:", df.duplicated().sum())

df = df.drop_duplicates()

print("New Shape:", df.shape)
# Out:
# Duplicate Rows: 0
# New Shape: (918, 12)

# %%
chol_zero = (df["Cholesterol"] == 0).sum()
bp_zero = (df["RestingBP"] == 0).sum()

print("Cholesterol = 0 :", chol_zero)
print("RestingBP = 0 :", bp_zero)
# Out:
# Cholesterol = 0 : 172
# RestingBP = 0 : 1

# %%
print("Before Cleaning")
print(df[["Cholesterol","RestingBP"]].describe())

chol_mean = df.loc[df["Cholesterol"] != 0, "Cholesterol"].mean()
bp_mean = df.loc[df["RestingBP"] != 0, "RestingBP"].mean()

df["Cholesterol"] = df["Cholesterol"].replace(0, chol_mean)
df["RestingBP"] = df["RestingBP"].replace(0, bp_mean)

df["Cholesterol"] = df["Cholesterol"].round(2)
df["RestingBP"] = df["RestingBP"].round(2)

print("After Cleaning")
print(df[["Cholesterol","RestingBP"]].describe())
# Out:
# Before Cleaning
#        Cholesterol   RestingBP
# count   918.000000  918.000000
# mean    198.799564  132.396514
# std     109.384145   18.514154
# min       0.000000    0.000000
# 25%     173.250000  120.000000
# 50%     223.000000  130.000000
# 75%     267.000000  140.000000
# max     603.000000  200.000000
# After Cleaning
#        Cholesterol   RestingBP
# count   918.000000  918.000000
# mean    244.636253  132.540893
# std      53.318029   17.989932
# min      85.000000   80.000000
# 25%     214.000000  120.000000
# 50%     244.640000  130.000000
# 75%     267.000000  140.000000
# max     603.000000  200.000000

# %%
import matplotlib.pyplot as plt

def plot_histograms(df):
    cols = ["Age","RestingBP","Cholesterol","MaxHR"]

    plt.figure(figsize=(10,8))

    for i,col in enumerate(cols):
        plt.subplot(2,2,i+1)
        plt.hist(df[col], bins=15)
        plt.title(col)

    plt.tight_layout()
    plt.show()

plot_histograms(df)

# %%
num_cols = df.select_dtypes(include=["int64","float64"]).columns
cat_cols = df.select_dtypes(include=["object"]).columns

print("Numerical Columns")
print(num_cols)

print("\nCategorical Columns")
print(cat_cols)
# Out:
# Numerical Columns
# Index(['Age', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'Oldpeak',
#        'HeartDisease'],
#       dtype='object')
#
# Categorical Columns
# Index(['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope'], dtype='object')

# %%
df_encoded = pd.get_dummies(df)

print("Shape:", df_encoded.shape)
print(df_encoded.head())
# Out:
# Shape: (918, 21)
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0   40      140.0        289.0          0    172      0.0             0
# 1   49      160.0        180.0          0    156      1.0             1
# 2   37      130.0        283.0          0     98      0.0             0
# 3   48      138.0        214.0          0    108      1.5             1
# 4   54      150.0        195.0          0    122      0.0             0
#
#    Sex_F  Sex_M  ChestPainType_ASY  ...  ChestPainType_NAP  ChestPainType_TA  \
# 0  False   True              False  ...              False             False
# 1   True  False              False  ...               True             False
# 2  False   True              False  ...              False             False
# 3   True  False               True  ...              False             False
# 4  False   True              False  ...               True             False
#
# ...

# %%
print("Final Shape:", df_encoded.shape)

print("\nColumn Names")
print(df_encoded.columns.tolist())
# Out:
# Final Shape: (918, 21)
#
# Column Names
# ['Age', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'Oldpeak', 'HeartDisease', 'Sex_F', 'Sex_M', 'ChestPainType_ASY', 'ChestPainType_ATA', 'ChestPainType_NAP', 'ChestPainType_TA', 'RestingECG_LVH', 'RestingECG_Normal', 'RestingECG_ST', 'ExerciseAngina_N', 'ExerciseAngina_Y', 'ST_Slope_Down', 'ST_Slope_Flat', 'ST_Slope_Up']

# %%
import pandas as pd

df = pd.read_csv("heart.csv")

# %%
print("========== SUMMARY ==========")
print("1. Invalid values found:")
print("- Cholesterol = 0")
print("- RestingBP = 0")

print("\n2. These invalid values were replaced using the mean of non-zero values.")

print("\n3. One-Hot Encoding converts categorical columns into numerical columns for Machine Learning.")

print("\n4. Duplicate rows were removed (if present) and the dataset was cleaned successfully.")
# Out:
# ========== SUMMARY ==========
# 1. Invalid values found:
# - Cholesterol = 0
# - RestingBP = 0
#
# 2. These invalid values were replaced using the mean of non-zero values.
#
# 3. One-Hot Encoding converts categorical columns into numerical columns for Machine Learning.
#
# 4. Duplicate rows were removed (if present) and the dataset was cleaned successfully.
